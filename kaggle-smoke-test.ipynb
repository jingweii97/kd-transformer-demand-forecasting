# %%
# %cd /kaggle/working/kd-transformer-demand-forecasting
# Out:
# /kaggle/working/kd-transformer-demand-forecasting

# %%
# !git status

# %%
# !git pull https://github.com/jingweii97/kd-transformer-demand-forecasting
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 488 bytes | 244.00 KiB/s, done.
# From https://github.com/jingweii97/kd-transformer-demand-forecasting
#  * branch            HEAD       -> FETCH_HEAD
# Updating 745ec7b..1a84232
# Fast-forward
#  scripts/evaluate_models.py | 16 ++++++++++------
#  1 file changed, 10 insertions(+), 6 deletions(-)

# %%
# !pip install -r requirements.txt

# %%
# !python scripts/prepare_dataset.py \
    --env kaggle
# Out:
# Stores to process    : ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3']
# Cache feature version: 2
# [SKIP] CA_1 — valid cache v2 already exists.
# [SKIP] CA_2 — valid cache v2 already exists.
# [SKIP] CA_3 — valid cache v2 already exists.
# [SKIP] CA_4 — valid cache v2 already exists.
# [SKIP] TX_1 — valid cache v2 already exists.
# [SKIP] TX_2 — valid cache v2 already exists.
# [SKIP] TX_3 — valid cache v2 already exists.
# [SKIP] WI_1 — valid cache v2 already exists.
# [SKIP] WI_2 — valid cache v2 already exists.
# [SKIP] WI_3 — valid cache v2 already exists.
#
# Dataset preparation stage completed successfully.

# %%
# !python scripts/train_teacher.py \
    --env kaggle \
    --epochs 1 \
    --max-stores 2 \
    --max-batches-per-store 1
# Out:
# ^C

# %%
# !python scripts/generate_soft_targets.py \
#     --env kaggle \
#     --checkpoint-path "/kaggle/working/kd-transformer-demand-forecasting/outputs/teacher/exp_001/best_tft_teacher.ckpt" \
#     --exp-name smoke \
#     --max-day 128

CUDA_VISIBLE_DEVICES=0

# %%
# !python scripts/generate_soft_targets.py \
    --env kaggle \
    --checkpoint-path "/kaggle/working/kd-transformer-demand-forecasting/outputs/teacher/exp_001/best_tft_teacher.ckpt" \
    --exp-name smoke \
    --max-day 128
# Out:
# Seed set to 42
# Loading 10 store Parquet file(s)...
# /kaggle/working/kd-transformer-demand-forecasting/data/cache.py:157: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("id")["time_idx"].is_monotonic_increasing.all()
# Building base training dataset...
# Loading global metadata builder from cache: /kaggle/working/kd-transformer-demand-forecasting/artifacts/metadata/global_metadata.pkl
# Loading TFT teacher model from checkpoint: /kaggle/working/kd-transformer-demand-forecasting/outputs/teacher/exp_001/best_tft_teacher.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# ...

# %%
# !python scripts/train_student.py \
    --env kaggle \
    --no-kd \
    --epochs 1 \
    --max-stores 2 \
    --max-batches-per-store 1
# Out:
# Seed set to 42
# Loading 10 store Parquet file(s)...
# /kaggle/working/kd-transformer-demand-forecasting/data/cache.py:157: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("id")["time_idx"].is_monotonic_increasing.all()
# Building TimeSeriesDataSet objects...
# Loading global metadata builder from cache: /kaggle/working/kd-transformer-demand-forecasting/artifacts/metadata/global_metadata.pkl
# Instantiating Compact Transformer Student model...
# Merged config saved to /kaggle/working/kd-transformer-demand-forecasting/outputs/student/no_kd/exp_001/config.yaml
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# ...

# %%
# !python scripts/train_student.py \
    --env kaggle \
    --kd \
    --soft-targets-path artifacts/soft_targets/smoke.pt \
    --epochs 1 \
    --max-stores 2 \
    --max-batches-per-store 1
# Out:
# Seed set to 42
# Loading 10 store Parquet file(s)...
# /kaggle/working/kd-transformer-demand-forecasting/data/cache.py:157: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("id")["time_idx"].is_monotonic_increasing.all()
# Building TimeSeriesDataSet objects...
# Loading global metadata builder from cache: /kaggle/working/kd-transformer-demand-forecasting/artifacts/metadata/global_metadata.pkl
# Loading pre-computed teacher forecasts from: /kaggle/working/kd-transformer-demand-forecasting/artifacts/soft_targets/smoke.pt
# Loaded soft targets tensor of shape: torch.Size([30491, 1942, 28])
# Instantiating Compact Transformer Student model...
# Merged config saved to /kaggle/working/kd-transformer-demand-forecasting/outputs/student/kd/exp_001/config.yaml
# ...

# %%
# !python scripts/evaluate_models.py \
    --env kaggle
# Out:
# Seed set to 42
# Loading 10 store Parquet file(s)...
# /kaggle/working/kd-transformer-demand-forecasting/data/cache.py:157: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("id")["time_idx"].is_monotonic_increasing.all()
# Building datasets and dataloaders...
# Loading global metadata builder from cache: /kaggle/working/kd-transformer-demand-forecasting/artifacts/metadata/global_metadata.pkl
# Loading models from checkpoints...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# ...
