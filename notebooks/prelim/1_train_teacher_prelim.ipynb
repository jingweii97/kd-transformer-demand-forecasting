# %% [markdown]
# # M5 Demand Forecasting - Step 1: Train TFT Teacher (Preliminary Experiment)
#
# ## 1. Description
# > [!NOTE]
# > **Preliminary Run Configuration**: This notebook is configured for the **preliminary experiment** (Texas subset via the `prelim` experiment profile). The original notebooks remain the workflow for the full experiments.
#
# - **Purpose**: Clone the repository, install dependencies, and train the Temporal Fusion Transformer (TFT) Teacher Model on the Texas stores subset.
# - **Required Input Datasets**:
#   - M5 Forecasting Accuracy raw dataset mounted under `/kaggle/input/competitions/m5-forecasting-accuracy`.
#   - Preprocessed dataset artifacts mounted under `/kaggle/input/datasets/jingweii97/kd-transformer-demand-forecasting-dataset/artifacts`.
# - **Generated Outputs**:
#   - Teacher model checkpoint, metrics, and merged config saved under `/kaggle/working/outputs/teacher/prelim/`.

# %% [markdown]
# ## 2. Shared Notebook Setup
# Clone the repository and install all python dependencies.

# %%
import os

if not os.path.exists("/kaggle/working/kd-transformer-demand-forecasting"):
    # !git clone https://github.com/jingweii97/kd-transformer-demand-forecasting

# %cd /kaggle/working/kd-transformer-demand-forecasting

# !git pull

# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Train Teacher Model
# Run the training script for the Temporal Fusion Transformer model using the `prelim` experiment configuration with experiment name `prelim`.

# %%
# !python scripts/train_teacher.py --env kaggle --experiment prelim --exp-name prelim

# %% [markdown]
# ## 4. Print Generated Outputs
# Verify the model checkpoints and merged config files.

# %%
import glob
print("TFT Teacher Checkpoints & Configs:")
for f in sorted(glob.glob("/kaggle/working/outputs/teacher/prelim/*")):
    print(f"  {f} ({os.path.getsize(f)/1e6:.2f} MB)")
