# %% [markdown]
# # M5 Demand Forecasting - Step 3: Train Student No KD (Preliminary Experiment)
#
# ## 1. Description
# > [!NOTE]
# > **Preliminary Run Configuration**: This notebook is configured for the **preliminary experiment** (Texas subset via the `prelim` experiment profile). The original notebooks remain the workflow for the full experiments.
#
# - **Purpose**: Clone the repository, install dependencies, and train the baseline Student model (compact Transformer) without Knowledge Distillation on the Texas stores subset, using only hard targets (ground-truth sales).
# - **Required Input Datasets**:
#   - M5 Forecasting Accuracy raw dataset mounted under `/kaggle/input/competitions/m5-forecasting-accuracy`.
#   - Preprocessed dataset artifacts mounted under `/kaggle/input/datasets/jingweii97/kd-transformer-demand-forecasting-dataset/artifacts`.
# - **Generated Outputs**:
#   - Baseline Student model checkpoint, metrics, and merged config saved under `/kaggle/working/outputs/student/no_kd/prelim/`.

# %% [markdown]
# ## 2. Shared Notebook Setup
# Clone the repository and install all python dependencies.

# %%
import os

if not os.path.exists("/kaggle/working/kd-transformer-demand-forecasting"):
    # !git clone https://github.com/jingweii97/kd-transformer-demand-forecasting

# %cd /kaggle/working/kd-transformer-demand-forecasting

# !git pull

# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Train Student (No KD) Model
# Train the student model without Knowledge Distillation by passing `--no-kd` under the `prelim` experiment configuration with experiment name `prelim`.

# %%
# !python scripts/train_student.py --env kaggle --experiment prelim --exp-name prelim --no-kd

# %% [markdown]
# ## 4. Print Generated Outputs
# Verify the model checkpoints generated for the Student (No KD) baseline run.

# %%
import glob
print("Student (No KD) Outputs:")
for f in sorted(glob.glob("/kaggle/working/outputs/student/no_kd/prelim/*")):
    print(f"  {f} ({os.path.getsize(f)/1e6:.2f} MB)")
