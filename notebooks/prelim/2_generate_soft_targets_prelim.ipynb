# %% [markdown]
# # M5 Demand Forecasting - Step 2: Generate Soft Targets (Preliminary Experiment)
#
# ## 1. Description
# > [!NOTE]
# > **Preliminary Run Configuration**: This notebook is configured for the **preliminary experiment** (Texas subset via the `prelim` experiment profile). The original notebooks remain the workflow for the full experiments.
#
# - **Purpose**: Clone the repository, install dependencies, and generate sliding-window soft target forecasts for training the student model using the trained TFT Teacher Model on the Texas stores subset.
# - **Required Input Datasets**:
#   - M5 Forecasting Accuracy raw dataset mounted under `/kaggle/input/competitions/m5-forecasting-accuracy`.
#   - Preprocessed dataset artifacts mounted under `/kaggle/input/datasets/jingweii97/kd-transformer-demand-forecasting-dataset/artifacts`.
#   - Teacher model checkpoint saved under `/kaggle/working/outputs/teacher/prelim/`.
# - **Generated Outputs**:
#   - Generated soft target forecasts (`prelim.pt` and provenance sidecar) saved under `/kaggle/working/artifacts/soft_targets/`.

# %% [markdown]
# ## 2. Shared Notebook Setup
# Clone the repository and install all python dependencies.

# %%
import os

if not os.path.exists("/kaggle/working/kd-transformer-demand-forecasting"):
    # !git clone https://github.com/jingweii97/kd-transformer-demand-forecasting

# %cd /kaggle/working/kd-transformer-demand-forecasting

# !git pull

# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Generate Soft Targets
# Execute the forecast precomputation script to generate soft targets from the trained teacher model checkpoint under the `prelim` experiment configuration.

# %%
# !python scripts/generate_soft_targets.py --env kaggle --experiment prelim --exp-name prelim --checkpoint-path /kaggle/working/outputs/teacher/prelim/best_tft_teacher.ckpt

# %% [markdown]
# ## 4. Print Generated Outputs
# Verify the model checkpoints and generated soft targets tensor files.

# %%
import glob
print("Precomputed Soft Targets:")
for f in sorted(glob.glob("/kaggle/working/artifacts/soft_targets/*")):
    print(f"  {f} ({os.path.getsize(f)/1e6:.2f} MB)")
