# %% [markdown]
# # M5 Demand Forecasting - Step 2: Train Student (No KD)
#
# ## 1. Description
# - **Purpose**: Clone the repository, install dependencies, and train the baseline Student model (compact Transformer) without Knowledge Distillation using only hard targets (ground-truth sales).
# - **Required Input Datasets**:
#   - M5 Forecasting Accuracy raw dataset mounted under `/kaggle/input/competitions/m5-forecasting-accuracy`.
#   - Preprocessed dataset artifacts mounted under `/kaggle/input/kd-transformer-demand-forecasting-dataset/artifacts`.
# - **Generated Outputs**:
#   - Baseline Student model checkpoint, metrics, and merged config saved under `/kaggle/working/outputs/student/no_kd/exp_001/`.

# %% [markdown]
# ## 2. Shared Notebook Setup
# Clone the repository and install all python dependencies.

# %%
import os

if not os.path.exists("/kaggle/working/kd-transformer-demand-forecasting"):
    # !git clone https://github.com/jingweii97/kd-transformer-demand-forecasting

# %cd /kaggle/working/kd-transformer-demand-forecasting

# !git pull

# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Train Student (No KD) Model
# Train the student model without Knowledge Distillation by passing `--no-kd` to the training script under the Kaggle environment.

# %%
# !python scripts/train_student.py --env kaggle --exp-name exp_001 --no-kd

# %% [markdown]
# ## 4. Print Generated Outputs
# Verify the model checkpoints generated for the Student (No KD) baseline run.

# %%
import glob
print("Student (No KD) Outputs:")
for f in sorted(glob.glob("/kaggle/working/outputs/student/no_kd/exp_001/*")):
    print(f"  {f} ({os.path.getsize(f)/1e6:.2f} MB)")
